# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielWalendolf/fundamentos-de-inteligencia-artificial/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula de IA teste de ambiente

# %%
print("Hey cara")
# Out:
# Hey cara
